# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('../../../Downloads/bct-summit/train.csv',index_col='id')
df.head()
# Out:
#     Age     BusinessTravel  DailyRate              Department  \
# id
# 0    36  Travel_Frequently        599  Research & Development
# 1    35      Travel_Rarely        921                   Sales
# 2    32      Travel_Rarely        718                   Sales
# 3    38      Travel_Rarely       1488  Research & Development
# 4    50      Travel_Rarely       1017  Research & Development
#
#     DistanceFromHome  Education EducationField  EmployeeCount  \
# id
# 0                 24          3        Medical              1
# 1                  8          3          Other              1
# 2                 26          3      Marketing              1
# 3                  2          3        Medical              1
# 4                  5          4        Medical              1
#
#     EnvironmentSatisfaction  Gender  ...  StandardHours  StockOptionLevel  \
# id                                   ...
# 0                         4    Male  ...             80                 1
# 1                         1    Male  ...             80                 1
# 2                         3    Male  ...             80                 2
# 3                         3  Female  ...             80                 0
# 4                         2  Female  ...             80                 0
#
#     TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  \
# id
# 0                  10                     2                3             10
# 1                   4                     3                3              4
# 2                   4                     3                3              3
# 3                  15                     1                1              6
# 4                  31                     0                3             31
#
#     YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# id
# 0                    0                        7                     8
# 1                    2                        0                     3
# 2                    2                        1                     2
# 3                    0                        0                     2
# 4                   14                        4                    10
#
#    Attrition
# id
# 0          0
# 1          0
# 2          0
# 3          0
# 4          1
#
# [5 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition'],
#       dtype='object')

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1677.000000  1677.000000       1677.000000  1677.000000         1677.0
# mean     36.036971   892.749553          8.683959     2.937984            1.0
# std       8.507112   374.496259          7.826143     1.039078            0.0
# min      18.000000   107.000000          1.000000     1.000000            1.0
# 25%      30.000000   589.000000          2.000000     2.000000            1.0
# 50%      35.000000   890.000000          7.000000     3.000000            1.0
# 75%      41.000000  1223.000000         12.000000     4.000000            1.0
# max      60.000000  3921.000000         29.000000    15.000000            1.0
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1677.000000  1677.000000     1677.000000  1677.000000
# mean                  2.757901    67.798450        2.782349     1.998807
# std                   1.086835    19.435928        0.650664     1.083065
# min                   1.000000    30.000000        1.000000     1.000000
# 25%                   2.000000    51.000000        2.000000     1.000000
# 50%                   3.000000    69.000000        3.000000     2.000000
# 75%                   4.000000    84.000000        3.000000     2.000000
# max                   4.000000   100.000000        4.000000     7.000000
#
#        JobSatisfaction  ...  StandardHours  StockOptionLevel  \
# count      1677.000000  ...         1677.0       1677.000000
# mean          2.791890  ...           80.0          0.721527
# std           1.097396  ...            0.0          0.771259
# min           1.000000  ...           80.0          0.000000
# 25%           2.000000  ...           80.0          0.000000
# 50%           3.000000  ...           80.0          1.000000
# 75%           4.000000  ...           80.0          1.000000
# max           4.000000  ...           80.0          3.000000
#
#        TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# count        1677.000000            1677.000000      1677.000000
# mean           10.709600               2.732856         2.769827
# std             7.255135               1.145271         0.647721
# min             0.000000               0.000000         1.000000
# 25%             6.000000               2.000000         2.000000
# 50%             9.000000               3.000000         3.000000
# 75%            14.000000               3.000000         3.000000
# max            41.000000               6.000000         4.000000
#
#        YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# count     1677.000000         1677.000000              1677.000000
# mean         6.806798            4.144305                 1.978533
# std          5.883282            3.583398                 3.045716
# min          0.000000            0.000000                 0.000000
# 25%          3.000000            2.000000                 0.000000
# 50%          5.000000            3.000000                 1.000000
# 75%          9.000000            7.000000                 2.000000
# max         41.000000           18.000000                15.000000
#
#        YearsWithCurrManager    Attrition
# count           1677.000000  1677.000000
# mean               4.186643     0.119261
# std                3.576189     0.324192
# min                0.000000     0.000000
# 25%                2.000000     0.000000
# 50%                3.000000     0.000000
# 75%                7.000000     0.000000
# max               17.000000     1.000000
#
# [8 rows x 26 columns]

# %%
df.isnull().sum()
# Out:
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# Attrition                   0
# dtype: int64

# %%
# Create a figure with a specific size
plt.figure(figsize=[20, 10])

for i, col in enumerate(df.columns):
    plt.subplot(8, 3, i+1)
    plt.hist(df[col])
    
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\WORK\OneDrive\Documents\drug_order_chatbot\attrition.ipynb Cell 6 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/WORK/OneDrive/Documents/drug_order_chatbot/attrition.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> plt.figure(figsize=[20, 10])
#       <a href='vscode-notebook-cell:/c%3A/Users/WORK/OneDrive/Documents/drug_order_chatbot/attrition.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> for i, col in enumerate(df.columns):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/WORK/OneDrive/Documents/drug_order_chatbot/attrition.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a>     plt.subplot(8, 3, i+1)
#       <a href='vscode-notebook-cell:/c%3A/Users/WORK/OneDrive/Documents/drug_order_chatbot/attrition.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a>     plt.hist(df[col])
#       <a href='vscode-notebook-cell:/c%3A/Users/WORK/OneDrive/Documents/drug_order_chatbot/attrition.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a>     plt.title(f'Histogram of {col}')
#
# File c:\Users\WORK\OneDrive\Documents\drug_order_chatbot\venv\lib\site-packages\matplotlib\pyplot.py:1425, in subplot(*args, **kwargs)
#    1422 fig = gcf()
#    1424 # First, search for an existing subplot with a matching spec.
# -> 1425 key = SubplotSpec._from_subplot_args(fig, args)
#    1427 for ax in fig.axes:
#    1428     # If we found an Axes at the position, we can re-use it if the user passed no
#    1429     # kwargs or if the axes class and kwargs are identical.
#    1430     if (ax.get_subplotspec() == key
#    1431         and (kwargs == {}
#    1432              or (ax._projection_init
#    1433                  == fig._process_projection_requirements(**kwargs)))):
#
# File c:\Users\WORK\OneDrive\Documents\drug_order_chatbot\venv\lib\site-packages\matplotlib\gridspec.py:599, in SubplotSpec._from_subplot_args(figure, args)
#     597 else:
#     598     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 599         raise ValueError(
#     600             f"num must be an integer with 1 <= num <= {rows*cols}, "
#     601             f"not {num!r}"
#     602         )
#     603     i = j = num
#     604 return gs[i-1:j]
#
# ValueError: num must be an integer with 1 <= num <= 24, not 25

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\WORK\OneDrive\Documents\drug_order_chatbot\attrition.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/WORK/OneDrive/Documents/drug_order_chatbot/attrition.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> sns.pairplot(data=df)
#
# File c:\Users\WORK\OneDrive\Documents\drug_order_chatbot\venv\lib\site-packages\seaborn\axisgrid.py:2163, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2161 if kind == "scatter":
#    2162     from .relational import scatterplot  # Avoid circular import
# -> 2163     plotter(scatterplot, **plot_kws)
#    2164 elif kind == "reg":
#    2165     from .regression import regplot  # Avoid circular import
#
# File c:\Users\WORK\OneDrive\Documents\drug_order_chatbot\venv\lib\site-packages\seaborn\axisgrid.py:1425, in PairGrid.map_offdiag(self, func, **kwargs)
#    1414 """Plot with a bivariate function on the off-diagonal subplots.
#    1415
#    1416 Parameters
#    (...)
#    1422
#    1423 """
#    1424 if self.square_grid:
# -> 1425     self.map_lower(func, **kwargs)
#    1426     if not self._corner:
#    1427         self.map_upper(func, **kwargs)
#
# File c:\Users\WORK\OneDrive\Documents\drug_order_chatbot\venv\lib\site-packages\seaborn\axisgrid.py:1395, in PairGrid.map_lower(self, func, **kwargs)
#    1384 """Plot with a bivariate function on the lower diagonal subplots.
#    1385
#    1386 Parameters
#    (...)
#    1392
#    1393 """
#    1394 indices = zip(*np.tril_indices_from(self.axes, -1))
# -> 1395 self._map_bivariate(func, indices, **kwargs)
#    1396 return self
#
# File c:\Users\WORK\OneDrive\Documents\drug_order_chatbot\venv\lib\site-packages\seaborn\axisgrid.py:1574, in PairGrid._map_bivariate(self, func, indices, **kwargs)
#    1572     if ax is None:  # i.e. we are in corner mode
#    1573         continue
# -> 1574     self._plot_bivariate(x_var, y_var, ax, func, **kws)
#    1575 self._add_axis_labels()
#    1577 if "hue" in signature(func).parameters:
#
# File c:\Users\WORK\OneDrive\Documents\drug_order_chatbot\venv\lib\site-packages\seaborn\axisgrid.py:1615, in PairGrid._plot_bivariate(self, x_var, y_var, ax, func, **kwargs)
#    1611 if "hue" not in kwargs:
#    1612     kwargs.update({
#    1613         "hue": hue, "hue_order": self._hue_order, "palette": self._orig_palette,
#    1614     })
# -> 1615 func(x=x, y=y, **kwargs)
#    1617 self._update_legend_data(ax)
#
# File c:\Users\WORK\OneDrive\Documents\drug_order_chatbot\venv\lib\site-packages\seaborn\relational.py:624, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     621 color = kwargs.pop("color", None)
#     622 kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
# --> 624 p.plot(ax, kwargs)
#     626 return ax
#
# File c:\Users\WORK\OneDrive\Documents\drug_order_chatbot\venv\lib\site-packages\seaborn\relational.py:398, in _ScatterPlotter.plot(self, ax, kws)
#     394 def plot(self, ax, kws):
#     395
#     396     # --- Determine the visual attributes of the plot
# --> 398     data = self.comp_data.dropna()
#     399     if data.empty:
#     400         return
#
# File c:\Users\WORK\OneDrive\Documents\drug_order_chatbot\venv\lib\site-packages\seaborn\_base.py:991, in VectorPlotter.comp_data(self)
#     989 parts = []
#     990 grouped = self.plot_data[var].groupby(self.converters[var], sort=False)
# --> 991 for converter, orig in grouped:
#     992     orig = orig.mask(orig.isin([np.inf, -np.inf]), np.nan)
#     993     orig = orig.dropna()
#
# File c:\Users\WORK\OneDrive\Documents\drug_order_chatbot\venv\lib\site-packages\pandas\core\groupby\ops.py:602, in BaseGrouper.get_iterator(self, data, axis)
#     591 def get_iterator(
#     592     self, data: NDFrameT, axis: AxisInt = 0
#     593 ) -> Iterator[tuple[Hashable, NDFrameT]]:
#     594     """
#     595     Groupby iterator
#     596
#    (...)
#     600     for each group
#     601     """
# --> 602     splitter = self._get_splitter(data, axis=axis)
#     603     keys = self.group_keys_seq
#     604     yield from zip(keys, splitter)
#
# File c:\Users\WORK\OneDrive\Documents\drug_order_chatbot\venv\lib\site-packages\pandas\core\groupby\ops.py:618, in BaseGrouper._get_splitter(self, data, axis)
#     608 """
#     609 Returns
#     610 -------
#     611 Generator yielding subsetted objects
#     612 """
#     613 ids, _, ngroups = self.group_info
#     614 return _get_splitter(
#     615     data,
#     616     ids,
#     617     ngroups,
# --> 618     sorted_ids=self._sorted_ids,
#     619     sort_idx=self._sort_idx,
#     620     axis=axis,
#     621 )
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File c:\Users\WORK\OneDrive\Documents\drug_order_chatbot\venv\lib\site-packages\pandas\core\groupby\ops.py:936, in BaseGrouper._sorted_ids(self)
#     932 @final
#     933 @cache_readonly
#     934 def _sorted_ids(self) -> npt.NDArray[np.intp]:
#     935     ids, _, _ = self.group_info
# --> 936     return ids.take(self._sort_idx)
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File c:\Users\WORK\OneDrive\Documents\drug_order_chatbot\venv\lib\site-packages\pandas\core\groupby\ops.py:930, in BaseGrouper._sort_idx(self)
#     925 @final
#     926 @cache_readonly
#     927 def _sort_idx(self) -> npt.NDArray[np.intp]:
#     928     # Counting sort indexer
#     929     ids, _, ngroups = self.group_info
# --> 930     return get_group_index_sorter(ids, ngroups)
#
# File c:\Users\WORK\OneDrive\Documents\drug_order_chatbot\venv\lib\site-packages\pandas\core\sorting.py:721, in get_group_index_sorter(group_index, ngroups)
#     719 do_groupsort = count > 0 and ((alpha + beta * ngroups) < (count * np.log(count)))
#     720 if do_groupsort:
# --> 721     sorter, _ = algos.groupsort_indexer(
#     722         ensure_platform_int(group_index),
#     723         ngroups,
#     724     )
#     725     # sorter _should_ already be intp, but mypy is not yet able to verify
#     726 else:
#     727     sorter = group_index.argsort(kind="mergesort")
#
# KeyboardInterrupt:
